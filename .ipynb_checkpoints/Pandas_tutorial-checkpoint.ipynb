# %%
import pandas as pd

mydataset = {
    'cars':["BMW", "Volvo", "Toyota", "Ford"],
    'passings':[3,2,7,5]
}

myvar = pd.DataFrame(mydataset)
print(myvar)
# Out:
#      cars  passings
# 0     BMW         3
# 1   Volvo         2
# 2  Toyota         7
# 3    Ford         5

# %%
print(pd.__version__)
# Out:
# 2.3.3
